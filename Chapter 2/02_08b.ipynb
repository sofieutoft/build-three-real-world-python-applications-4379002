# %% [markdown]
# # Exploring Alpha Vantage API

# %% [markdown]
# ### Imports- **Run First**

# %%
#open file with your API key
with open('Alpha_Vantage_API_key.txt') as file:
    API_key = file.read()
API_key = API_key.strip()

# %%
#import libraries
from alpha_vantage.timeseries import TimeSeries

import requests
from bs4 import BeautifulSoup

import pandas as pd
import io

# %%
#build TimeSeries variable from Alpha Vantage API
ts1 = TimeSeries(key = API_key)

# %% [markdown]
# ### How to put stock data into a DataFrame

# %% [markdown]
# #### Requests Method

# %%
#get weekly stock data of Apple in DataFrame format
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY&symbol=AAPL&apikey=' + str(API_key) + '&datatype=csv'
r = requests.get(url).content
data = pd.read_csv(io.StringIO(r.decode('utf-8')))

print(data)
# Out:
#        timestamp    open     high     low   close     volume
# 0     2023-10-04  171.22  174.300  170.82  173.66  154779434
# 1     2023-09-29  174.20  176.970  167.62  171.21  285838995
# 2     2023-09-22  176.48  179.695  173.86  174.79  297395196
# 3     2023-09-15  180.07  180.300  173.58  175.01  403746390
# 4     2023-09-08  188.28  189.980  173.54  178.18  305126712
# ...          ...     ...      ...     ...     ...        ...
# 1243  1999-12-10  114.56  118.000   99.00  103.00   25152800
# 1244  1999-12-03   94.25  115.560   93.25  115.00   28046300
# 1245  1999-11-26   91.75   95.500   88.50   95.06    9757600
# 1246  1999-11-19   89.62   94.750   88.06   92.44   13711000
# 1247  1999-11-12   87.75   97.730   86.75   90.62   25776200
#
# [1248 rows x 6 columns]

# %%
#get head of data
data.head(10)
# Out:
#     timestamp    open     high      low   close     volume
# 0  2023-10-04  171.22  174.300  170.820  173.66  154779434
# 1  2023-09-29  174.20  176.970  167.620  171.21  285838995
# 2  2023-09-22  176.48  179.695  173.860  174.79  297395196
# 3  2023-09-15  180.07  180.300  173.580  175.01  403746390
# 4  2023-09-08  188.28  189.980  173.540  178.18  305126712
# 5  2023-09-01  180.09  189.920  178.545  189.46  264199503
# 6  2023-08-25  175.07  181.550  173.735  178.61  247514268
# 7  2023-08-18  177.97  179.690  171.960  174.49  261498109
# 8  2023-08-11  182.13  183.130  176.550  177.79  332501087
# 9  2023-08-04  196.06  196.730  181.920  181.99  302694989

# %% [markdown]
# #### Python Package Method

# %%
#store Apple stock intraday data in data and meta_data variables
apple1, meta_data = ts1.get_intraday('AAPL')

# %%
#print meta_data
meta_data
# Out:
# {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#  '2. Symbol': 'AAPL',
#  '3. Last Refreshed': '2023-10-04 19:45:00',
#  '4. Interval': '15min',
#  '5. Output Size': 'Compact',
#  '6. Time Zone': 'US/Eastern'}

# %%
#print data
apple1
# Out:
# {'2023-10-04 19:45:00': {'1. open': '173.4300',
#   '2. high': '173.4300',
#   '3. low': '173.2600',
#   '4. close': '173.2700',
#   '5. volume': '13598'},
#  '2023-10-04 19:30:00': {'1. open': '173.4200',
#   '2. high': '173.4400',
#   '3. low': '173.3800',
#   '4. close': '173.4200',
#   '5. volume': '6162'},
#  '2023-10-04 19:15:00': {'1. open': '173.3300',
#   '2. high': '173.4300',
#   '3. low': '173.3300',
#   '4. close': '173.4300',
#   '5. volume': '5012'},
#  '2023-10-04 19:00:00': {'1. open': '173.3300',
#   '2. high': '173.4300',
#   '3. low': '173.3100',
#   '4. close': '173.3650',
#   '5. volume': '2059'},
#  '2023-10-04 18:45:00': {'1. open': '173.3900',
#   '2. high': '173.4000',
#   '3. low': '173.3000',
#   '4. close': '173.3500',
#   '5. volume': '5435'},
#  '2023-10-04 18:30:00': {'1. open': '173.3600',
#   '2. high': '173.4500',
#   '3. low': '173.2700',
#   '4. close': '173.3900',
#   '5. volume': '12057'},
#  '2023-10-04 18:15:00': {'1. open': '173.3000',
#   '2. high': '173.4300',
#   '3. low': '173.2500',
#   '4. close': '173.3210',
#   '5. volume': '12079'},
#  '2023-10-04 18:00:00': {'1. open': '173.3400',
#   '2. high': '173.3900',
#   '3. low': '173.2500',
#   '4. close': '173.2900',
#   '5. volume': '8786'},
#  '2023-10-04 17:45:00': {'1. open': '173.4300',
#   '2. high': '173.4400',
#   '3. low': '173.3100',
#   '4. close': '173.3100',
#   '5. volume': '5198'},
#  '2023-10-04 17:30:00': {'1. open': '173.3000',
#   '2. high': '173.4400',
#   '3. low': '173.2500',
#   '4. close': '173.4300',
#   '5. volume': '13902'},
#  '2023-10-04 17:15:00': {'1. open': '173.4600',
#   '2. high': '180.3740',
#   '3. low': '173.2100',
#   '4. close': '173.3100',
#   '5. volume': '15797'},
#  '2023-10-04 17:00:00': {'1. open': '173.5200',
#   '2. high': '173.9300',
#   '3. low': '173.4300',
#   '4. close': '173.4600',
#   '5. volume': '17503'},
#  '2023-10-04 16:45:00': {'1. open': '173.5500',
#   '2. high': '173.6600',
#   '3. low': '173.5000',
#   '4. close': '173.5300',
#   '5. volume': '99779'},
#  '2023-10-04 16:30:00': {'1. open': '173.5200',
#   '2. high': '173.6600',
#   '3. low': '173.5000',
#   '4. close': '173.5450',
#   '5. volume': '64343'},
#  '2023-10-04 16:15:00': {'1. open': '173.6100',
#   '2. high': '173.6600',
#   '3. low': '173.5200',
#   '4. close': '173.5300',
#   '5. volume': '395491'},
#  '2023-10-04 16:00:00': {'1. open': '173.6600',
#   '2. high': '173.6600',
#   '3. low': '173.1100',
#   '4. close': '173.6300',
#   '5. volume': '11979662'},
#  '2023-10-04 15:45:00': {'1. open': '173.9350',
#   '2. high': '173.9800',
#   '3. low': '173.3700',
#   '4. close': '173.6600',
#   '5. volume': '6016013'},
#  '2023-10-04 15:30:00': {'1. open': '173.7700',
#   '2. high': '174.2100',
#   '3. low': '173.7150',
#   '4. close': '173.9400',
#   '5. volume': '1802453'},
#  '2023-10-04 15:15:00': {'1. open': '173.4200',
#   '2. high': '173.8150',
#   '3. low': '173.3950',
#   '4. close': '173.7700',
#   '5. volume': '2051105'},
#  '2023-10-04 15:00:00': {'1. open': '173.0900',
#   '2. high': '173.5100',
#   '3. low': '173.0300',
#   '4. close': '173.4250',
#   '5. volume': '1491585'},
#  '2023-10-04 14:45:00': {'1. open': '173.0000',
#   '2. high': '173.1400',
#   '3. low': '172.8500',
#   '4. close': '173.0790',
#   '5. volume': '749450'},
#  '2023-10-04 14:30:00': {'1. open': '172.7400',
#   '2. high': '173.0300',
#   '3. low': '172.6100',
#   '4. close': '173.0000',
#   '5. volume': '827358'},
#  '2023-10-04 14:15:00': {'1. open': '172.6300',
#   '2. high': '172.8250',
#   '3. low': '172.3500',
#   '4. close': '172.7400',
#   '5. volume': '1001272'},
#  '2023-10-04 14:00:00': {'1. open': '172.5150',
#   '2. high': '172.7500',
#   '3. low': '172.3700',
#   '4. close': '172.6290',
#   '5. volume': '956252'},
#  '2023-10-04 13:45:00': {'1. open': '172.8400',
#   '2. high': '172.9200',
#   '3. low': '172.4600',
#   '4. close': '172.5200',
#   '5. volume': '943757'},
#  '2023-10-04 13:30:00': {'1. open': '172.6800',
#   '2. high': '172.8400',
#   '3. low': '172.4800',
#   '4. close': '172.8320',
#   '5. volume': '934001'},
#  '2023-10-04 13:15:00': {'1. open': '173.0000',
#   '2. high': '173.1200',
#   '3. low': '172.6450',
#   '4. close': '172.6800',
#   '5. volume': '881832'},
#  '2023-10-04 13:00:00': {'1. open': '173.1000',
#   '2. high': '173.1300',
#   '3. low': '172.8700',
#   '4. close': '173.0000',
#   '5. volume': '754653'},
#  '2023-10-04 12:45:00': {'1. open': '173.0400',
#   '2. high': '173.2000',
#   '3. low': '172.9900',
#   '4. close': '173.1100',
#   '5. volume': '695658'},
#  '2023-10-04 12:30:00': {'1. open': '173.1700',
#   '2. high': '173.2600',
#   '3. low': '172.9700',
#   '4. close': '173.0400',
#   '5. volume': '825979'},
#  '2023-10-04 12:15:00': {'1. open': '172.9700',
#   '2. high': '173.2900',
#   '3. low': '172.9000',
#   '4. close': '173.1700',
#   '5. volume': '904074'},
#  '2023-10-04 12:00:00': {'1. open': '173.1400',
#   '2. high': '173.2300',
#   '3. low': '172.8100',
#   '4. close': '172.9600',
#   '5. volume': '1181844'},
#  '2023-10-04 11:45:00': {'1. open': '172.7200',
#   '2. high': '173.1500',
#   '3. low': '172.6200',
#   '4. close': '173.1400',
#   '5. volume': '1239374'},
#  '2023-10-04 11:30:00': {'1. open': '172.8600',
#   '2. high': '172.9000',
#   '3. low': '172.4100',
#   '4. close': '172.7200',
#   '5. volume': '1126935'},
#  '2023-10-04 11:15:00': {'1. open': '172.5100',
#   '2. high': '173.1350',
#   '3. low': '172.4800',
#   '4. close': '172.8600',
#   '5. volume': '1545200'},
#  '2023-10-04 11:00:00': {'1. open': '172.4400',
#   '2. high': '172.5900',
#   '3. low': '171.8600',
#   '4. close': '172.5100',
#   '5. volume': '1801945'},
#  '2023-10-04 10:45:00': {'1. open': '173.1600',
#   '2. high': '173.3300',
#   '3. low': '172.3000',
#   '4. close': '172.4500',
#   '5. volume': '2000459'},
#  '2023-10-04 10:30:00': {'1. open': '172.4000',
#   '2. high': '173.4900',
#   '3. low': '172.4000',
#   '4. close': '173.1600',
#   '5. volume': '3007875'},
#  '2023-10-04 10:15:00': {'1. open': '172.6500',
#   '2. high': '172.7400',
#   '3. low': '172.2000',
#   '4. close': '172.3950',
#   '5. volume': '2116216'},
#  '2023-10-04 10:00:00': {'1. open': '172.4800',
#   '2. high': '172.7000',
#   '3. low': '171.8700',
#   '4. close': '172.6400',
#   '5. volume': '2924606'},
#  '2023-10-04 09:45:00': {'1. open': '172.1800',
#   '2. high': '172.6900',
#   '3. low': '172.1120',
#   '4. close': '172.4900',
#   '5. volume': '2624682'},
#  '2023-10-04 09:30:00': {'1. open': '171.0900',
#   '2. high': '172.4600',
#   '3. low': '170.9700',
#   '4. close': '172.1800',
#   '5. volume': '4206950'},
#  '2023-10-04 09:15:00': {'1. open': '171.3100',
#   '2. high': '171.5000',
#   '3. low': '170.8600',
#   '4. close': '171.1200',
#   '5. volume': '168586'},
#  '2023-10-04 09:00:00': {'1. open': '171.6400',
#   '2. high': '172.4000',
#   '3. low': '171.3000',
#   '4. close': '171.3100',
#   '5. volume': '173543'},
#  '2023-10-04 08:45:00': {'1. open': '171.6200',
#   '2. high': '173.3900',
#   '3. low': '171.4750',
#   '4. close': '171.6200',
#   '5. volume': '99171'},
#  '2023-10-04 08:30:00': {'1. open': '171.2300',
#   '2. high': '171.7600',
#   '3. low': '171.2100',
#   '4. close': '171.6400',
#   '5. volume': '66206'},
#  '2023-10-04 08:15:00': {'1. open': '171.1500',
#   '2. high': '172.4000',
#   '3. low': '171.1100',
#   '4. close': '171.2300',
#   '5. volume': '186157'},
#  '2023-10-04 08:00:00': {'1. open': '170.6950',
#   '2. high': '172.4000',
#   '3. low': '169.2700',
#   '4. close': '171.1500',
#   '5. volume': '133035'},
#  '2023-10-04 07:45:00': {'1. open': '170.8900',
#   '2. high': '171.0400',
#   '3. low': '170.7600',
#   '4. close': '170.8700',
#   '5. volume': '31925'},
#  '2023-10-04 07:30:00': {'1. open': '170.8400',
#   '2. high': '170.9300',
#   '3. low': '170.6500',
#   '4. close': '170.8600',
#   '5. volume': '29410'},
#  '2023-10-04 07:15:00': {'1. open': '170.9800',
#   '2. high': '171.0900',
#   '3. low': '170.7300',
#   '4. close': '170.8400',
#   '5. volume': '52422'},
#  '2023-10-04 07:00:00': {'1. open': '170.7300',
#   '2. high': '171.2600',
#   '3. low': '170.6500',
#   '4. close': '170.9800',
#   '5. volume': '49759'},
#  '2023-10-04 06:45:00': {'1. open': '170.5400',
#   '2. high': '170.7600',
#   '3. low': '170.3300',
#   '4. close': '170.6800',
#   '5. volume': '7546'},
#  '2023-10-04 06:30:00': {'1. open': '170.7300',
#   '2. high': '170.8300',
#   '3. low': '170.4100',
#   '4. close': '170.5400',
#   '5. volume': '8979'},
#  '2023-10-04 06:15:00': {'1. open': '170.7600',
#   '2. high': '170.9500',
#   '3. low': '170.6900',
#   '4. close': '170.7400',
#   '5. volume': '7733'},
#  '2023-10-04 06:00:00': {'1. open': '170.5800',
#   '2. high': '170.8000',
#   '3. low': '170.4100',
#   '4. close': '170.7600',
#   '5. volume': '11683'},
#  '2023-10-04 05:45:00': {'1. open': '170.5800',
#   '2. high': '170.7000',
#   '3. low': '170.3500',
#   '4. close': '170.4500',
#   '5. volume': '7277'},
#  '2023-10-04 05:30:00': {'1. open': '170.4500',
#   '2. high': '170.7200',
#   '3. low': '170.4000',
#   '4. close': '170.5800',
#   '5. volume': '15458'},
#  '2023-10-04 05:15:00': {'1. open': '170.3300',
#   '2. high': '170.4900',
#   '3. low': '170.1800',
#   '4. close': '170.4500',
#   '5. volume': '7391'},
#  '2023-10-04 05:00:00': {'1. open': '170.2500',
#   '2. high': '170.3600',
#   '3. low': '170.0000',
#   '4. close': '170.3300',
#   '5. volume': '16413'},
#  '2023-10-04 04:45:00': {'1. open': '169.9000',
#   '2. high': '170.3900',
#   '3. low': '169.9000',
#   '4. close': '170.2900',
#   '5. volume': '20127'},
#  '2023-10-04 04:30:00': {'1. open': '170.1600',
#   '2. high': '170.2700',
#   '3. low': '169.8000',
#   '4. close': '169.8800',
#   '5. volume': '36693'},
#  '2023-10-04 04:15:00': {'1. open': '170.1600',
#   '2. high': '170.2700',
#   '3. low': '169.8200',
#   '4. close': '170.2200',
#   '5. volume': '26200'},
#  '2023-10-04 04:00:00': {'1. open': '170.0000',
#   '2. high': '170.4800',
#   '3. low': '169.2600',
#   '4. close': '170.1600',
#   '5. volume': '47246'},
#  '2023-10-03 19:45:00': {'1. open': '171.4000',
#   '2. high': '171.4000',
#   '3. low': '170.8500',
#   '4. close': '170.8800',
#   '5. volume': '58446'},
#  '2023-10-03 19:30:00': {'1. open': '171.2500',
#   '2. high': '171.5000',
#   '3. low': '171.1100',
#   '4. close': '171.3900',
#   '5. volume': '34698'},
#  '2023-10-03 19:15:00': {'1. open': '171.0500',
#   '2. high': '171.3700',
#   '3. low': '171.0200',
#   '4. close': '171.2500',
#   '5. volume': '19703'},
#  '2023-10-03 19:00:00': {'1. open': '172.0800',
#   '2. high': '172.1600',
#   '3. low': '171.0100',
#   '4. close': '171.0500',
#   '5. volume': '77720'},
#  '2023-10-03 18:45:00': {'1. open': '172.0350',
#   '2. high': '172.1700',
#   '3. low': '171.9700',
#   '4. close': '172.0800',
#   '5. volume': '1988'},
#  '2023-10-03 18:30:00': {'1. open': '172.1300',
#   '2. high': '188.0800',
#   '3. low': '171.9400',
#   '4. close': '172.0350',
#   '5. volume': '3433'},
#  '2023-10-03 18:15:00': {'1. open': '171.9500',
#   '2. high': '172.1700',
#   '3. low': '171.9300',
#   '4. close': '172.0500',
#   '5. volume': '13529'},
#  '2023-10-03 18:00:00': {'1. open': '172.0500',
#   '2. high': '172.1900',
#   '3. low': '171.9200',
#   '4. close': '171.9700',
#   '5. volume': '18627'},
#  '2023-10-03 17:45:00': {'1. open': '172.0500',
#   '2. high': '196.4500',
#   '3. low': '172.0000',
#   '4. close': '172.0200',
#   '5. volume': '12556'},
#  '2023-10-03 17:30:00': {'1. open': '172.0600',
#   '2. high': '176.2880',
#   '3. low': '172.0000',
#   '4. close': '172.0250',
#   '5. volume': '11166'},
#  '2023-10-03 17:15:00': {'1. open': '172.1800',
#   '2. high': '172.4000',
#   '3. low': '167.0030',
#   '4. close': '172.0500',
#   '5. volume': '132962'},
#  '2023-10-03 17:00:00': {'1. open': '172.0800',
#   '2. high': '172.2700',
#   '3. low': '172.0800',
#   '4. close': '172.1500',
#   '5. volume': '8255'},
#  '2023-10-03 16:45:00': {'1. open': '172.3000',
#   '2. high': '172.4000',
#   '3. low': '172.0600',
#   '4. close': '172.1200',
#   '5. volume': '99815'},
#  '2023-10-03 16:30:00': {'1. open': '172.3600',
#   '2. high': '172.4000',
#   '3. low': '172.2300',
#   '4. close': '172.3000',
#   '5. volume': '61337'},
#  '2023-10-03 16:15:00': {'1. open': '172.4000',
#   '2. high': '172.4000',
#   '3. low': '172.3200',
#   '4. close': '172.3550',
#   '5. volume': '119082'},
#  '2023-10-03 16:00:00': {'1. open': '172.4700',
#   '2. high': '172.5650',
#   '3. low': '172.2280',
#   '4. close': '172.3300',
#   '5. volume': '11574620'},
#  '2023-10-03 15:45:00': {'1. open': '172.0900',
#   '2. high': '172.5200',
#   '3. low': '172.0200',
#   '4. close': '172.4600',
#   '5. volume': '4447650'},
#  '2023-10-03 15:30:00': {'1. open': '171.8550',
#   '2. high': '172.2460',
#   '3. low': '171.7800',
#   '4. close': '172.0850',
#   '5. volume': '1804496'},
#  '2023-10-03 15:15:00': {'1. open': '171.8300',
#   '2. high': '172.2000',
#   '3. low': '171.7900',
#   '4. close': '171.8600',
#   '5. volume': '1374616'},
#  '2023-10-03 15:00:00': {'1. open': '172.2600',
#   '2. high': '172.3000',
#   '3. low': '171.8050',
#   '4. close': '171.8300',
#   '5. volume': '1363883'},
#  '2023-10-03 14:45:00': {'1. open': '172.2100',
#   '2. high': '172.4000',
#   '3. low': '172.0800',
#   '4. close': '172.2700',
#   '5. volume': '1262225'},
#  '2023-10-03 14:30:00': {'1. open': '171.8500',
#   '2. high': '172.2300',
#   '3. low': '171.8150',
#   '4. close': '172.2190',
#   '5. volume': '820779'},
#  '2023-10-03 14:15:00': {'1. open': '171.6950',
#   '2. high': '172.0200',
#   '3. low': '171.5600',
#   '4. close': '171.8500',
#   '5. volume': '1009663'},
#  '2023-10-03 14:00:00': {'1. open': '171.9700',
#   '2. high': '172.1300',
#   '3. low': '171.5510',
#   '4. close': '171.7000',
#   '5. volume': '1063565'},
#  '2023-10-03 13:45:00': {'1. open': '171.9700',
#   '2. high': '172.0550',
#   '3. low': '171.7700',
#   '4. close': '171.9700',
#   '5. volume': '823636'},
#  '2023-10-03 13:30:00': {'1. open': '172.0100',
#   '2. high': '172.0950',
#   '3. low': '171.7500',
#   '4. close': '171.9650',
#   '5. volume': '877331'},
#  '2023-10-03 13:15:00': {'1. open': '172.2700',
#   '2. high': '172.3100',
#   '3. low': '171.9650',
#   '4. close': '172.0020',
#   '5. volume': '914440'},
#  '2023-10-03 13:00:00': {'1. open': '172.5500',
#   '2. high': '172.8050',
#   '3. low': '172.1200',
#   '4. close': '172.2700',
#   '5. volume': '1317507'},
#  '2023-10-03 12:45:00': {'1. open': '172.4260',
#   '2. high': '172.6900',
#   '3. low': '172.3600',
#   '4. close': '172.5600',
#   '5. volume': '1185883'},
#  '2023-10-03 12:30:00': {'1. open': '172.2800',
#   '2. high': '172.6700',
#   '3. low': '172.2400',
#   '4. close': '172.4300',
#   '5. volume': '1309713'},
#  '2023-10-03 12:15:00': {'1. open': '171.9900',
#   '2. high': '172.3650',
#   '3. low': '171.9200',
#   '4. close': '172.2640',
#   '5. volume': '1253100'},
#  '2023-10-03 12:00:00': {'1. open': '171.7480',
#   '2. high': '172.0900',
#   '3. low': '171.6900',
#   '4. close': '172.0000',
#   '5. volume': '1224958'},
#  '2023-10-03 11:45:00': {'1. open': '171.8000',
#   '2. high': '171.8400',
#   '3. low': '171.4300',
#   '4. close': '171.7500',
#   '5. volume': '886169'},
#  '2023-10-03 11:30:00': {'1. open': '171.6300',
#   '2. high': '171.8400',
#   '3. low': '171.3600',
#   '4. close': '171.8100',
#   '5. volume': '1128624'},
#  '2023-10-03 11:15:00': {'1. open': '171.8400',
#   '2. high': '171.9850',
#   '3. low': '171.5500',
#   '4. close': '171.6400',
#   '5. volume': '1369152'},
#  '2023-10-03 11:00:00': {'1. open': '171.5000',
#   '2. high': '171.8800',
#   '3. low': '171.3900',
#   '4. close': '171.8350',
#   '5. volume': '1825757'}}

# %%
#store data into a DataFrame
df_apple1 = pd.DataFrame(apple1).transpose().reset_index()
df_apple1.head()
# Out:
#                  index   1. open   2. high    3. low  4. close 5. volume
# 0  2023-10-04 19:45:00  173.4300  173.4300  173.2600  173.2700     13598
# 1  2023-10-04 19:30:00  173.4200  173.4400  173.3800  173.4200      6162
# 2  2023-10-04 19:15:00  173.3300  173.4300  173.3300  173.4300      5012
# 3  2023-10-04 19:00:00  173.3300  173.4300  173.3100  173.3650      2059
# 4  2023-10-04 18:45:00  173.3900  173.4000  173.3000  173.3500      5435

# %%
#Bring in data in DataFrame format
ts2 = TimeSeries(key = API_key, output_format = 'pandas')

# %%
# display new intraday stock data
ts2.get_intraday('AAPL')
# Out:
# (                     1. open  2. high  3. low  4. close  5. volume
#  date
#  2023-10-04 19:45:00  173.430  173.430  173.26   173.270    13598.0
#  2023-10-04 19:30:00  173.420  173.440  173.38   173.420     6162.0
#  2023-10-04 19:15:00  173.330  173.430  173.33   173.430     5012.0
#  2023-10-04 19:00:00  173.330  173.430  173.31   173.365     2059.0
#  2023-10-04 18:45:00  173.390  173.400  173.30   173.350     5435.0
#  ...                      ...      ...     ...       ...        ...
#  2023-10-03 12:00:00  171.748  172.090  171.69   172.000  1224958.0
#  2023-10-03 11:45:00  171.800  171.840  171.43   171.750   886169.0
#  2023-10-03 11:30:00  171.630  171.840  171.36   171.810  1128624.0
#  2023-10-03 11:15:00  171.840  171.985  171.55   171.640  1369152.0
#  2023-10-03 11:00:00  171.500  171.880  171.39   171.835  1825757.0
#
#  [100 rows x 5 columns],
#  {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#   '2. Symbol': 'AAPL',
#   '3. Last Refreshed': '2023-10-04 19:45:00',
#   '4. Interval': '15min',
#   '5. Output Size': 'Compact',
#   '6. Time Zone': 'US/Eastern'})

# %%
#get full amount of intraday stock data for data and meta_data
df_apple2, meta_data = ts2.get_intraday('AAPL', outputsize = 'full')

# %%
#print meta_data
meta_data
# Out:
# {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#  '2. Symbol': 'AAPL',
#  '3. Last Refreshed': '2023-10-04 19:45:00',
#  '4. Interval': '15min',
#  '5. Output Size': 'Full size',
#  '6. Time Zone': 'US/Eastern'}

# %%
#print data with reset index
df_apple2.reset_index()
# Out:
#                     date  1. open  2. high  3. low  4. close  5. volume
# 0    2023-10-04 19:45:00   173.43   173.43  173.26   173.270    13598.0
# 1    2023-10-04 19:30:00   173.42   173.44  173.38   173.420     6162.0
# 2    2023-10-04 19:15:00   173.33   173.43  173.33   173.430     5012.0
# 3    2023-10-04 19:00:00   173.33   173.43  173.31   173.365     2059.0
# 4    2023-10-04 18:45:00   173.39   173.40  173.30   173.350     5435.0
# ...                  ...      ...      ...     ...       ...        ...
# 1019 2023-09-13 05:00:00   175.91   175.92  175.40   175.650    31718.0
# 1020 2023-09-13 04:45:00   176.04   176.24  175.81   175.810    42808.0
# 1021 2023-09-13 04:30:00   176.63   176.90  175.93   176.040    45996.0
# 1022 2023-09-13 04:15:00   176.58   176.72  176.35   176.650    20493.0
# 1023 2023-09-13 04:00:00   176.35   177.00  176.06   176.540    56514.0
#
# [1024 rows x 6 columns]
